# %%
from ultralytics import YOLO
import matplotlib.pyplot as plt

# %%
model = YOLO("./yolo11s-seg.pt")

# %%
results = model.train(data="./YOLO-style-annotations/data.yaml", epochs=250, batch=8, patience=0, lr0=0.001, lrf=0.001, imgsz=800)
# Out:
# Ultralytics 8.3.79  Python-3.13.0 torch-2.6.0+cu118 CUDA:0 (NVIDIA GeForce GTX 1070, 8192MiB)
# ...

# %%
model = YOLO("../runs/segment/train21/weights/best.pt")
new_res = model.predict("F:\\Diploma\\for_annotation\\DURSEN\\DRUSEN-163081-1.jpeg", conf=0.3)
for_plot = new_res[0].plot(boxes=False)
plt.imsave("test.jpeg",for_plot)
